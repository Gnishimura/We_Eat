# %%
import pandas as pd

# %%
from database_fxn import (
    load_api_key, make_request, build_database, default_params,
    retrieve_database)

# %%
api_key = load_api_key()

# %%
data = make_request(default_params, api_key)

# %%
data[0].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'price', 'location', 'phone', 'display_phone', 'distance'])

# %%
pd.DataFrame(data)
# Out:
#                                                 alias  \
# 0                              il-corvo-pasta-seattle
# 1                                 amazon-go-seattle-5
# 2                             the-pink-door-seattle-4
# 3                                     nirmals-seattle
# 4                                  bad-bishop-seattle
# 5                          pike-place-chowder-seattle
# 6                             biscuit-bitch-seattle-5
# 7                            damn-the-weather-seattle
# 8                                 tsukushinbo-seattle
# 9               taylor-shellfish-oyster-bar-seattle-2
# 10                    elliotts-oyster-house-seattle-2
# 11                dough-zone-dumpling-house-seattle-2
# 12                         the-london-plane-seattle-3
# 13                        a-hong-kong-kitchen-seattle
# 14                              shake-shack-seattle-3
# 15                           radiator-whiskey-seattle
# ...

# %%
build_database(location='98101')
# Out:
# 1
# 51
# 101
# 151
# 201
# 251
# 301
# 351
# 401
# 451
# 501
# 551
# 601
# 651
# 701
# 751
# 801
# 851
# 901
# 951
# No businesses returned

# %%
df = retrieve_database()

# %%
df.shape
# Out:
# (1239, 17)

# %%
df
# Out:
#                           _id  \
# 0    5bf5e06f91d56f59f158cfa4
# 1    5bf5e06f91d56f59f158cfa5
# 2    5bf5e06f91d56f59f158cfa6
# 3    5bf5e06f91d56f59f158cfa7
# 4    5bf5e06f91d56f59f158cfa8
# 5    5bf5e06f91d56f59f158cfa9
# 6    5bf5e06f91d56f59f158cfaa
# 7    5bf5e06f91d56f59f158cfab
# 8    5bf5e06f91d56f59f158cfac
# 9    5bf5e06f91d56f59f158cfad
# 10   5bf5e06f91d56f59f158cfae
# 11   5bf5e06f91d56f59f158cfaf
# 12   5bf5e06f91d56f59f158cfb0
# 13   5bf5e06f91d56f59f158cfb1
# 14   5bf5e06f91d56f59f158cfb2
# 15   5bf5e06f91d56f59f158cfb3
# 16   5bf5e06f91d56f59f158cfb4
# 17   5bf5e06f91d56f59f158cfb5
# 18   5bf5e06f91d56f59f158cfb6
# 19   5bf5e06f91d56f59f158cfb7
# 20   5bf5e06f91d56f59f158cfb8
# 21   5bf5e06f91d56f59f158cfb9
# 22   5bf5e06f91d56f59f158cfba
# 23   5bf5e06f91d56f59f158cfbb
# 24   5bf5e06f91d56f59f158cfbc
# 25   5bf5e06f91d56f59f158cfbd
# 26   5bf5e06f91d56f59f158cfbe
# 27   5bf5e06f91d56f59f158cfbf
# 28   5bf5e06f91d56f59f158cfc0
# 29   5bf5e06f91d56f59f158cfc1
# ...
