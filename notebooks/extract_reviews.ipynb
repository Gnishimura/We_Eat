# %%
from pymongo import MongoClient
from bs4 import BeautifulSoup
import logging
import pandas as pd

we_eat_client = MongoClient()
we_eat_db = we_eat_client['we_eat']
website_collection = we_eat_db['websites']
review_collection = we_eat_db['reviews']

# %%
website_collection.count_documents({})
# Out:
# 657

# %%
website = website_collection.find_one()

# %%
def parse_review(review, alias):
    r = {}
    r['alias'] = alias
    r['username'] = review.select_one('li.user-name').text.strip()
    r['href'] = review.select_one('li.user-name a').attrs['href']
    r['userid'] = r['href'].partition('?userid=')[2]
    r['rating'] = float(review.select_one('div.i-stars').attrs['title'].partition(' ')[0])
    r['date'] = review.select_one('span.rating-qualifier').text.strip()
    r['review_text'] = review.select_one('div.review-content p').text
    return r

# %%
def collect_reviews(website_collection):
    for website in website_collection.find():
        url = website['url']
        print(url)
        logging.info(url)
        alias = url.rpartition('/')[2]
        html = website['html']
        soup = BeautifulSoup(html, 'html.parser')
        reviews = soup.select('div.review')
        for review in reviews[1:]:
            review_data = parse_review(review, alias)
            save_review(review_data)

# %%
def save_review(review_data):
    review_collection.delete_many({
        'alias': review_data['alias'],
        'userid': review_data['userid']
    })
    review_collection.insert_one(review_data)

# %%
collect_reviews(website_collection)
# Out:
# https://www.yelp.com/biz/amazon-go-seattle-5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a94a8291e7c4> in <module>()
# ----> 1 collect_reviews(website_collection)
#
# <ipython-input-12-705df527731c> in collect_reviews(website_collection)
#       9         reviews = soup.select('div.review')
#      10         for review in reviews[1:]:
# ---> 11             review_data = parse_review(review, alias)
#      12             save_review(review_data)
#      13
#
# <ipython-input-11-1045212bbc64> in parse_review(review, alias)
#       5     r['href'] = review.select_one('li.user-name a').attrs['href']
#       6     r['userid'] = r['href'].partition('?userid=')[2]
# ----> 7     r['rating'] = int(review.select_one('div.i-stars').attrs['title'].partition(' ')[0])
#       8     r['date'] = review.select_one('span.rating-qualifier').text.strip()
#       9     r['review_text'] = review.select_one('div.review-content p').text
#
# ValueError: invalid literal for int() with base 10: '5.0'

# %%
html = website['html']

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
reviews = soup.select('div.review')

# %%
#[review.text for review in reviews]

# %%
review = reviews[1]

# %%
review.select_one('li.user-name a')
# Out:
# <a class="user-display-name js-analytics-click" data-analytics-label="about_me" data-hovercard-id="Ytg6yFIK8NbNcVHBboKJPA" href="/user_details?userid=JuLCP_tSVkfgs6884f_SvQ" id="dropdown_user-name">Yan Z.</a>

# %%
review.select_one('div.i-stars')
# Out:
# <div class="i-stars i-stars--regular-5 rating-large" title="5.0 star rating">
# <img alt="5.0 star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9b34e39ccbeb/assets/img/stars/stars.png" width="84"/>
# </div>

# %%
review.select_one('span.rating-qualifier')
# Out:
# <span class="rating-qualifier">
#         11/1/2018
#     </span>

# %%
df = pd.DataFrame(list(review_collection.find()))

# %%
df.shape
# Out:
# (11431, 8)

# %%
names = df.userid.value_counts()

# %%
multiple_reviewers = names[names>1]

# %%
multiple_reviewers
# Out:
# iNIxjH-qoi0DW-0M2ML2DA    65
# YQ01_0vr9TahbQiBSr69Nw    42
# PSnUXFT5luMvb73mQQSjUg    36
# 4IsfIY1Df9dxEeDu7lHd5g    33
# NfU0zDaTMEQ4-X9dbQWd9A    32
# nfL3ilIVq58nvT1iqS_ZpQ    28
# on72W_uXxaomHGxxcM3S_w    27
# iztl5NRH01qvWA0LEICw8Q    26
# OGLkivfkMESvh-2Fkg3bjw    24
# a2osd_dBVDYaO-kL_Whjng    21
# oTae-gLGMpNNFxcBn2D77A    21
# 5ju4tmqmdYS3QquclUxIkg    20
# T0HWgeviH7722ZJpWFrB4Q    17
# 4teLaidLkOwhWuee9PET7g    17
# cKTA-iJbfrioKWFiDreghw    16
# KTz8KGjhIW3ejJ_RlTKH_g    16
# QtIPWTVbngTszYtBU8tCkQ    16
# P1FObQIDR0ErchMIKc05Xg    16
# s3OwzXmv5Xrd2OuYu8YmHw    15
# 7u5sOo6-W-iwAgg-yrXE6Q    14
# 7f6ZDbtiFvVK0Ajhb0fuAA    13
# 6yw_4m8IBhdPeAvQNbFMDw    13
# Mof6BV_iz_JP1RZvyg1sUw    13
# TiAunhv-wmGaUZvtox7xvg    13
# y79iXFlBPRO588FvlJVZWQ    13
# 6gMaEJU2xjRCPjiKYsB2Nw    13
# ATo6Yuweoi3ZVB0qNz34sw    13
# jC_eLNR8Le-FvQOK5jMi8g    12
# lcQRKGDkc_uRTK_Yqx5z-A    12
# zMKWSl7SxxPW3nidytb91g    12
#                           ..
# rrfHL-1xvGM3kDaXsNDkQA     2
# XRMArbiZOGNYFGlap9fBDA     2
# cczCUack5vpprurWhc0ckg     2
# but2s3yQA5LokHGCaVXHVg     2
# INJeBb5oMnS54FpUv894qw     2
# povvfHblniE-5IT_Bwe0qA     2
# -TWmOCrqnTwfO5k04S3QrA     2
# AjHlIIYfFCMmt5dJ3ldH7w     2
# Re_t7o_f67Jio-FKroOUlA     2
# Ah0QFiDbwS5RY9FVTBed9g     2
# 0FyfxrAMHm7AlrAkAXZQ9Q     2
# rpd2TTvEMSDgIJ19GyE31A     2
# DRmTd7sjXiMVdgQJmxrotQ     2
# Bp0wwAcjV35mUqcFB2WDZg     2
# 85bn2Nrpl-UMGplvldGO0A     2
# 0XZ4Ro6zXrHaPB8V2_J8gw     2
# vRRZbOGmmO2bi7IPLeurvA     2
# 0DnQxBz82tU--KsevUFCTw     2
# hBJh4bHy-ERPa4ALEnyoWw     2
# 2FhRK0mMlzbEu6OnFQ6_nw     2
# WSZ89d86HNninvfSJGzl6A     2
# lPL8LP9nE-9UxuKSiftLCQ     2
# _t9zUcTiLg7e2-UkSARRww     2
# IEKpcrfvmIXyTpN-hldgxA     2
# PGQYPm_OYZ_cbLAkHSMWlw     2
# kwcZaFdfZlGiFfeDxvuyNw     2
# lVDlEVh_i8bZ8OTJxK0Kqw     2
# uAu5pceZrX8Lwbi00jQKfg     2
# eft4wYgthxkkvjIA52Dbtg     2
# FJ_Us5rDjdXCkM9TQ1IDQA     2
# Name: userid, Length: 1524, dtype: int64

# %%
more_than_one_review = df[df.duplicated('userid', keep=False)]

# %%
more_than_one_review.shape
# Out:
# (5216, 8)

# %%
more_than_one_review.sort_values(by='userid')
# Out:
#                             _id                                    alias  \
# 159    5c07264e91d56fb8e2f0ac86          elliotts-oyster-house-seattle-2
# 4178   5c0726b191d56fb8e2f0bc39                        le-pichet-seattle
# 8629   5c07272891d56fb8e2f0cd9c                 cafe-nordstrom-seattle-5
# 6328   5c0726e991d56fb8e2f0c49f       delaurenti-food-and-wine-seattle-2
# 10296  5c07275691d56fb8e2f0d41f                   chip-and-drews-seattle
# 8083   5c07271991d56fb8e2f0cb7a      new-star-seafood-restaurant-seattle
# 4654   5c0726be91d56fb8e2f0be15                 fado-irish-pub-seattle-3
# 5486   5c0726d491d56fb8e2f0c155                  turkish-delight-seattle
# 7663   5c07270b91d56fb8e2f0c9d6                       tats-truck-seattle
# 8308   5c07271f91d56fb8e2f0cc5b             buffalo-wild-wings-seattle-2
# 1863   5c07267791d56fb8e2f0b32e      lan-huê-sandwich-and-bakery-seattle
# 9026   5c07273391d56fb8e2f0cf29                       663-bistro-seattle
# 4031   5c0726ad91d56fb8e2f0bba6                      saigon-deli-seattle
# 1362   5c07266b91d56fb8e2f0b139               sichuanese-cuisine-seattle
# 6768   5c0726f491d56fb8e2f0c657                  oriental-mart-seattle-5
# 648    5c07265a91d56fb8e2f0ae6f                           maneki-seattle
# 3397   5c07269e91d56fb8e2f0b92c                 okinawa-teriyaki-seattle
# 308    5c07265291d56fb8e2f0ad1b                  ummas-lunch-box-seattle
# 7647   5c07270b91d56fb8e2f0c9c6                    kidd-valley-seattle-6
# 164    5c07264e91d56fb8e2f0ac8b          elliotts-oyster-house-seattle-2
# 1365   5c07266b91d56fb8e2f0b13c               sichuanese-cuisine-seattle
# 1867   5c07267791d56fb8e2f0b332      lan-huê-sandwich-and-bakery-seattle
# 4890   5c0726c491d56fb8e2f0bf01               lowells-restaurant-seattle
# 2841   5c07268f91d56fb8e2f0b700                    hue-ky-mi-gia-seattle
# 4684   5c0726be91d56fb8e2f0be33      joyale-seafood-restaurant-seattle-2
# 6776   5c0726f591d56fb8e2f0c65f                 thanh-son-tofu-seattle-3
# 7068   5c0726fc91d56fb8e2f0c783                     union-square-seattle
# 2564   5c07268891d56fb8e2f0b5eb                      homegrown-seattle-5
# 6887   5c0726f891d56fb8e2f0c6ce                   duk-li-dim-sum-seattle
# 4851   5c0726c391d56fb8e2f0beda                   kaname-izakaya-seattle
# ...                         ...                                      ...
# 557    5c07265891d56fb8e2f0ae14           japonessa-sushi-cocina-seattle
# 1032   5c07266391d56fb8e2f0afef             intermezzo-carmine-seattle-2
# 1780   5c07267591d56fb8e2f0b2db                          outlier-seattle
# 9808   5c07274891d56fb8e2f0d237           seattle-bagel-bakery-seattle-5
# 4279   5c0726b491d56fb8e2f0bc9e                  happy-grillmore-seattle
# 9737   5c07274691d56fb8e2f0d1f0                    jimmy-johns-seattle-3
# 2595   5c07268991d56fb8e2f0b60a  stella-fiore-wood-fired-pizza-seattle-3
# 8520   5c07272591d56fb8e2f0cd2f              rub-with-love-shack-seattle
# 16     5c07264a91d56fb8e2f0abf7                  the-pink-door-seattle-4
# 11050  5c07276d91d56fb8e2f0d711                       quiznos-seattle-23
# 4861   5c0726c491d56fb8e2f0bee4                    steak-n-shake-seattle
# 9106   5c07273591d56fb8e2f0cf79           king-deli-and-espresso-seattle
# 10025  5c07274e91d56fb8e2f0d310                     bebas-deli-seattle-2
# 617    5c07265991d56fb8e2f0ae50               mikes-noodle-house-seattle
# 5976   5c0726e191d56fb8e2f0c33f              ulis-famous-sausage-seattle
# 1983   5c07267a91d56fb8e2f0b3a6                     spin-seattle-seattle
# 6156   5c0726e591d56fb8e2f0c3f3                purple-dot-cafe-seattle-2
# 5822   5c0726dd91d56fb8e2f0c2a5                    sushi-kudasai-seattle
# 10182  5c07275291d56fb8e2f0d3ad                     mcdonalds-seattle-27
# 10754  5c07276391d56fb8e2f0d5e9                  taste-of-asia-seattle-2
# 888    5c07266091d56fb8e2f0af5f                        ironsteak-seattle
# 8590   5c07272791d56fb8e2f0cd75          la-vaca-burrito-express-seattle
# 6391   5c0726eb91d56fb8e2f0c4de               evergreens-salad-seattle-4
# 6563   5c0726ef91d56fb8e2f0c58a                     seattle-deli-seattle
# 9339   5c07273b91d56fb8e2f0d062                      mangia-me-seattle-2
# 8025   5c07271791d56fb8e2f0cb40    specialtys-café-and-bakery-seattle-34
# 8003   5c07271691d56fb8e2f0cb2a                      sound-soups-seattle
# 6828   5c0726f691d56fb8e2f0c693              walla-walla-farms-seattle-3
# 8986   5c07273291d56fb8e2f0cf01                  saigon-bistro-seattle-2
# 5594   5c0726d791d56fb8e2f0c1c1                            tossd-seattle
#
#                                                     date  \
# 159    11/26/2018\n            \n\n\n\n\n\nUpdated re...
# 4178                                          10/19/2018
# 8629                                            7/7/2018
# 6328                                            8/6/2018
# 10296                                           9/4/2014
# 8083                                           3/14/2018
# 4654                                          10/19/2018
# 5486                                          10/19/2018
# 7663                                          11/12/2018
# 8308                                            5/2/2018
# 1863                                            9/9/2018
# 9026                                            3/8/2018
# 4031                                            8/2/2018
# 1362                                          10/23/2018
# 6768                                            2/8/2018
# 648                                           10/23/2018
# 3397                                          10/23/2018
# 308                                           10/23/2018
# 7647                                           3/27/2018
# 164                                           11/25/2018
# 1365                                          10/31/2018
# 1867                                          10/31/2018
# 4890                                          10/28/2018
# 2841                                          10/28/2018
# 4684                                           6/27/2018
# 6776                                           8/23/2018
# 7068                                          10/18/2012
# 2564                                          11/23/2018
# 6887                                           11/3/2018
# 4851                                          11/25/2016
# ...                                                  ...
# 557                                           10/26/2018
# 1032                                           11/4/2017
# 1780                                           11/8/2018
# 9808                                          10/26/2018
# 4279                                           3/14/2018
# 9737                                           9/25/2016
# 2595                                           1/10/2017
# 8520                                           11/3/2018
# 16                                             12/3/2018
# 11050                                          2/18/2009
# 4861                                          10/25/2018
# 9106                                            8/6/2012
# 10025                                          4/27/2012
# 617                                            6/11/2018
# 5976                                          10/11/2018
# 1983                                          10/14/2018
# 6156                                           10/4/2018
# 5822                                            7/7/2016
# 10182                                          5/24/2017
# 10754                                          6/30/2016
# 888                                             4/6/2018
# 8590                                           6/30/2016
# 6391                                            6/5/2017
# 6563                                           7/19/2017
# 9339                                            6/5/2017
# 8025                                           2/18/2017
# 8003                                          11/17/2015
# 6828                                            2/3/2016
# 8986                                           2/12/2018
# 5594                                           7/11/2018
#
#                                               href  rating  \
# 159    /user_details?userid=-0EvRubXjITOMSvLrMu76A     4.0
# 4178   /user_details?userid=-0EvRubXjITOMSvLrMu76A     5.0
# 8629   /user_details?userid=-Cys-ssZV8WqUc2Zvu-0Pg     4.0
# 6328   /user_details?userid=-Cys-ssZV8WqUc2Zvu-0Pg     5.0
# 10296  /user_details?userid=-D4T2oVxSjvVN9_owkEmyw     1.0
# 8083   /user_details?userid=-D4T2oVxSjvVN9_owkEmyw     3.0
# 4654   /user_details?userid=-DrzglrYFZG_qg_YtbknSQ     4.0
# 5486   /user_details?userid=-DrzglrYFZG_qg_YtbknSQ     4.0
# 7663   /user_details?userid=-EnSMkETzd9oKlu3Kc3_Ew     2.0
# 8308   /user_details?userid=-EnSMkETzd9oKlu3Kc3_Ew     1.0
# 1863   /user_details?userid=-EuXDbUI5Xkmq2tTf5SIIA     5.0
# 9026   /user_details?userid=-EuXDbUI5Xkmq2tTf5SIIA     4.0
# 4031   /user_details?userid=-EuXDbUI5Xkmq2tTf5SIIA     5.0
# 1362   /user_details?userid=-EuXDbUI5Xkmq2tTf5SIIA     3.0
# 6768   /user_details?userid=-EuXDbUI5Xkmq2tTf5SIIA     5.0
# 648    /user_details?userid=-EuXDbUI5Xkmq2tTf5SIIA     5.0
# 3397   /user_details?userid=-KxUYVuGT4-wNpYtLR-rcw     5.0
# 308    /user_details?userid=-KxUYVuGT4-wNpYtLR-rcw     5.0
# 7647   /user_details?userid=-OSh85r31TMUZbJHXhpdbA     5.0
# 164    /user_details?userid=-OSh85r31TMUZbJHXhpdbA     5.0
# 1365   /user_details?userid=-OqsUocE7ysl-uCd7NwQUg     5.0
# 1867   /user_details?userid=-OqsUocE7ysl-uCd7NwQUg     5.0
# 4890   /user_details?userid=-SG4RsYUN8Ho366mn63bng     4.0
# 2841   /user_details?userid=-SG4RsYUN8Ho366mn63bng     5.0
# 4684   /user_details?userid=-TWmOCrqnTwfO5k04S3QrA     4.0
# 6776   /user_details?userid=-TWmOCrqnTwfO5k04S3QrA     4.0
# 7068   /user_details?userid=-TtbBXTW_mCKdZ-mhqubTw     4.0
# 2564   /user_details?userid=-TtbBXTW_mCKdZ-mhqubTw     5.0
# 6887   /user_details?userid=-TtbBXTW_mCKdZ-mhqubTw     3.0
# 4851   /user_details?userid=-TtbBXTW_mCKdZ-mhqubTw     3.0
# ...                                            ...     ...
# 557    /user_details?userid=zeeeJ2q0NBxTnb5U_pZJiA     5.0
# 1032   /user_details?userid=zeeeJ2q0NBxTnb5U_pZJiA     5.0
# 1780   /user_details?userid=zeeeJ2q0NBxTnb5U_pZJiA     5.0
# 9808   /user_details?userid=zeeeJ2q0NBxTnb5U_pZJiA     5.0
# 4279   /user_details?userid=zgKzBdRAbEYWkqx7NmAa3Q     5.0
# 9737   /user_details?userid=zgKzBdRAbEYWkqx7NmAa3Q     1.0
# 2595   /user_details?userid=zgKzBdRAbEYWkqx7NmAa3Q     2.0
# 8520   /user_details?userid=zgUbT8l5xVlPo_ZpYFelkw     4.0
# 16     /user_details?userid=zgUbT8l5xVlPo_ZpYFelkw     4.0
# 11050  /user_details?userid=zjZOOgIRvFnGAO0QQ5FNQA     4.0
# 4861   /user_details?userid=zjZOOgIRvFnGAO0QQ5FNQA     2.0
# 9106   /user_details?userid=zlNGe-n0-NT2owDpNF1DQA     3.0
# 10025  /user_details?userid=zlNGe-n0-NT2owDpNF1DQA     2.0
# 617    /user_details?userid=zniE4E1xzRHp5WgvcyK3ag     4.0
# 5976   /user_details?userid=zniE4E1xzRHp5WgvcyK3ag     4.0
# 1983   /user_details?userid=zniE4E1xzRHp5WgvcyK3ag     3.0
# 6156   /user_details?userid=zniE4E1xzRHp5WgvcyK3ag     5.0
# 5822   /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     5.0
# 10182  /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     4.0
# 10754  /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     4.0
# 888    /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     3.0
# 8590   /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     4.0
# 6391   /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     5.0
# 6563   /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     4.0
# 9339   /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     3.0
# 8025   /user_details?userid=zq22rw_VB7eLhwrsZrmTDQ     5.0
# 8003   /user_details?userid=zshgxFvIaOBmpQkHZ2rGOA     2.0
# 6828   /user_details?userid=zshgxFvIaOBmpQkHZ2rGOA     3.0
# 8986   /user_details?userid=zw8pz2bK-nNnB8MdWJbc9w     3.0
# 5594   /user_details?userid=zw8pz2bK-nNnB8MdWJbc9w     3.0
#
#                                              review_text  \
# 159    Got the fish and chips - first two pieces of f...
# 4178   Hidden gem in Seattle. If you are looking for ...
# 8629   The staff at this cafe is amazing, from the ca...
# 6328   Large variety, super cool placeIf you like to ...
# 10296  You've gotta be kidding me.I work in the build...
# 8083   I feel like New Star is really expensive for C...
# 4654   Nice find if you like funky bars it's an Irish...
# 5486   Stopped in on a cold day and had the lentil so...
# 7663   Ordered an Italian hoagie which is always sold...
# 8308   Absolutely terrible experience here, and a gig...
# 1863   Bánh mi is good and cheap.  There is seating, ...
# 9026   This is for takeout.663 is rough around the ed...
# 4031   As a kid who grew up eating at places geared t...
# 1362   Review for you hot potheads out there:The hot ...
# 6768   No-bullshit Filipino food - they even tell you...
# 648    Home-style Japanese served with sass! And hist...
# 3397   had pork Katsu and Yakisoba combo, and I will ...
# 308    Been here two times already and I like their f...
# 7647   For me it is the best or 2nd fast food burger ...
# 164    One of the beat seafoods restaurants in the ar...
# 1365   I love this place. The mandarin spicy chicken,...
# 1867   Really enjoyed the Banh Mi here. Tried the bee...
# 4890   This is a good to breakfast spot when we come ...
# 2841   I love this place! Every time I come back home...
# 4684   I was home for a visit and wanted to throw a f...
# 6776   Holy Moley you wouldn't expect to find a place...
# 7068   I don't now why I can't find this place. Maybe...
# 2564   Delicious salad place in downtown Seattle. I'v...
# 6887   If you don't want to wait for your dim sum thi...
# 4851   A neighborhood joint.This place gets packed. T...
# ...                                                  ...
# 557    Good location, nice restaurant, pretty inside ...
# 1032   This place is so gorgeous. The inside... super...
# 1780   Beautiful restaurant. Love the location, downt...
# 9808   Pretty much the best bagel I have ever tasted,...
# 4279   BEST veggie burger I've ever had. I ordered th...
# 9737   I live right around the corner so I order from...
# 2595   Poor customer service, and the char is so inte...
# 8520   This was our first meal in Seattle for our 1st...
# 16     After reading rave reviews for The Pink Door, ...
# 11050  In the post-McDonald's era, the Subways and Qu...
# 4861   A seasoned yelper urged me to write this.Where...
# 9106   The key to enjoying the conglomerate of downto...
# 10025  The selection and convenience (for me) is nice...
# 617    I wasn't sure what to order because there are ...
# 5976   If you're at Pike place and visiting Seattle y...
# 1983   Happy hour is good for drinks and apps. It is ...
# 6156   I'm so glad Purple Dot is open for the late ni...
# 5822   This place is surprisingly good. It is probabl...
# 10182  It is odd that I am putting in a review for Mc...
# 10754  This is a buffet style take out place with a v...
# 888    I was excited to try this place since I've hea...
# 8590   I was so happy to find a good and cheap Mexica...
# 6391   Super amazing salad place with huge variety! T...
# 6563   Great spot to pick up some quick Vietnamese co...
# 9339   I tried the squid ink pasta and tiramisu. The ...
# 8025   This is a review for their catering and delive...
# 8003   Soup was OK (I had the fiesta chicken), but it...
# 6828   This place is average as far as quick downtown...
# 8986   The baguette wasn't toasted so it was chewy. N...
# 5594   I choose Athena.  The ingredients were cut ver...
#
#                        userid     username
# 159    -0EvRubXjITOMSvLrMu76A     Brian R.
# 4178   -0EvRubXjITOMSvLrMu76A     Brian R.
# 8629   -Cys-ssZV8WqUc2Zvu-0Pg    Rebeca G.
# 6328   -Cys-ssZV8WqUc2Zvu-0Pg    Rebeca G.
# 10296  -D4T2oVxSjvVN9_owkEmyw   Jonelle T.
# 8083   -D4T2oVxSjvVN9_owkEmyw   Jonelle T.
# 4654   -DrzglrYFZG_qg_YtbknSQ     Karen V.
# 5486   -DrzglrYFZG_qg_YtbknSQ     Karen V.
# 7663   -EnSMkETzd9oKlu3Kc3_Ew       Gun H.
# 8308   -EnSMkETzd9oKlu3Kc3_Ew       Gun H.
# 1863   -EuXDbUI5Xkmq2tTf5SIIA       Amy L.
# 9026   -EuXDbUI5Xkmq2tTf5SIIA       Amy L.
# 4031   -EuXDbUI5Xkmq2tTf5SIIA       Amy L.
# 1362   -EuXDbUI5Xkmq2tTf5SIIA       Amy L.
# 6768   -EuXDbUI5Xkmq2tTf5SIIA       Amy L.
# 648    -EuXDbUI5Xkmq2tTf5SIIA       Amy L.
# 3397   -KxUYVuGT4-wNpYtLR-rcw    Eugene L.
# 308    -KxUYVuGT4-wNpYtLR-rcw    Eugene L.
# 7647   -OSh85r31TMUZbJHXhpdbA      Anas J.
# 164    -OSh85r31TMUZbJHXhpdbA      Anas J.
# 1365   -OqsUocE7ysl-uCd7NwQUg     Misha B.
# 1867   -OqsUocE7ysl-uCd7NwQUg     Misha B.
# 4890   -SG4RsYUN8Ho366mn63bng      Leah W.
# 2841   -SG4RsYUN8Ho366mn63bng      Leah W.
# 4684   -TWmOCrqnTwfO5k04S3QrA       Ivy L.
# 6776   -TWmOCrqnTwfO5k04S3QrA       Ivy L.
# 7068   -TtbBXTW_mCKdZ-mhqubTw  Jennifer B.
# 2564   -TtbBXTW_mCKdZ-mhqubTw  Jennifer B.
# 6887   -TtbBXTW_mCKdZ-mhqubTw  Jennifer B.
# 4851   -TtbBXTW_mCKdZ-mhqubTw  Jennifer B.
# ...                       ...          ...
# 557    zeeeJ2q0NBxTnb5U_pZJiA    Mariah E.
# 1032   zeeeJ2q0NBxTnb5U_pZJiA    Mariah E.
# 1780   zeeeJ2q0NBxTnb5U_pZJiA    Mariah E.
# 9808   zeeeJ2q0NBxTnb5U_pZJiA    Mariah E.
# 4279   zgKzBdRAbEYWkqx7NmAa3Q  Samantha O.
# 9737   zgKzBdRAbEYWkqx7NmAa3Q  Samantha O.
# 2595   zgKzBdRAbEYWkqx7NmAa3Q  Samantha O.
# 8520   zgUbT8l5xVlPo_ZpYFelkw    Tricia G.
# 16     zgUbT8l5xVlPo_ZpYFelkw    Tricia G.
# 11050  zjZOOgIRvFnGAO0QQ5FNQA      Lily H.
# 4861   zjZOOgIRvFnGAO0QQ5FNQA      Lily H.
# 9106   zlNGe-n0-NT2owDpNF1DQA   Michael D.
# 10025  zlNGe-n0-NT2owDpNF1DQA   Michael D.
# 617    zniE4E1xzRHp5WgvcyK3ag      Phil M.
# 5976   zniE4E1xzRHp5WgvcyK3ag      Phil M.
# 1983   zniE4E1xzRHp5WgvcyK3ag      Phil M.
# 6156   zniE4E1xzRHp5WgvcyK3ag      Phil M.
# 5822   zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 10182  zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 10754  zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 888    zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 8590   zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 6391   zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 6563   zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 9339   zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 8025   zq22rw_VB7eLhwrsZrmTDQ     Jenny C.
# 8003   zshgxFvIaOBmpQkHZ2rGOA    angela c.
# 6828   zshgxFvIaOBmpQkHZ2rGOA    angela c.
# 8986   zw8pz2bK-nNnB8MdWJbc9w         C Y.
# 5594   zw8pz2bK-nNnB8MdWJbc9w         C Y.
#
# [5216 rows x 8 columns]

# %% [markdown]
# # Build dataframe for ALS model

# %%
aliases = more_than_one_review['alias'].unique()

# %%
alias_ids = zip(aliases, range(len(aliases)))

# %%
alias_dict = dict(alias_ids)

# %%
alias_dict
# Out:
# {'13-coins-restaurant-seattle-3': 179,
#  '1st-floor-cafe-seattle': 607,
#  '206-burger-company-seattle': 120,
#  '206-burger-company-seattle-2': 328,
#  '2nd-ave-gifts-and-sundries-seattle': 587,
#  '4th-ave-espresso-bar-seattle-3': 349,
#  '4th-avenue-caffe-seattle-2': 539,
#  '663-bistro-seattle': 473,
#  '90-karaoke-seattle-2': 336,
#  'a-hong-kong-kitchen-seattle': 12,
#  'a-pizza-mart-seattle-14': 445,
#  'aburiya-bento-house-seattle-2': 98,
#  'alaskan-sourdough-bakery-seattle': 145,
#  'alibi-room-seattle': 311,
#  'all-water-seafood-and-oyster-bar-seattle-2': 240,
#  'aloha-plates-seattle': 276,
#  'altstadt-seattle-2': 47,
#  'amazon-go-seattle-5': 0,
#  'andaluca-seattle-2': 308,
#  'apizza-seattle-3': 571,
#  'asia-bar-b-que-seattle': 564,
#  'asia-ginger-teriyaki-seattle': 277,
#  'asian-express-seattle': 525,
#  'atlantic-street-pizza-slices-seattle': 506,
#  'ba-bar-seattle': 126,
#  'bacco-cafe-and-bistro-seattle-2': 322,
#  'bad-bishop-seattle': 5,
#  'banh-cuon-tan-dinh-deli-seattle': 299,
#  'bao-house-seattle-5': 60,
#  'basil-box-seattle': 534,
#  'bavarian-meats-seattle': 317,
#  'bebas-and-amigos-seattle': 437,
#  'bebas-deli-seattle-2': 529,
#  'beechers-handmade-cheese-seattle': 140,
#  'belle-epicurean-seattle-5': 203,
#  'bernards-on-seneca-seattle': 466,
#  'bibimbap-king-seattle': 23,
#  'bibimbap-seattle': 54,
#  'biscuit-bitch-seattle': 39,
#  'biscuit-bitch-seattle-5': 3,
#  'blarney-stone-pub-and-restaurant-seattle': 340,
#  'blazing-bagels-seattle-2': 307,
#  'blue-c-sushi-seattle-3': 498,
#  'blue-nile-seattle-2': 510,
#  'blue-water-taco-grill-seattle-12': 420,
#  'blue-water-taco-grill-seattle-2': 604,
#  'blue-water-taco-grill-seattle-3': 457,
#  'blue-water-taco-grill-seattle-9': 550,
#  'boiling-point-seattle': 59,
#  'bookstore-bar-and-cafe-seattle-6': 303,
#  'bowls-and-noodles-seattle': 518,
#  'box-house-seattle-3': 414,
#  'brgr-bar-seattle-seattle': 27,
#  'buffalo-wild-wings-seattle-2': 433,
#  'bun-and-oc-seattle-4': 148,
#  'cafe-5ive-seattle': 515,
#  'cafe-hitchcock-seattle-2': 201,
#  'cafe-nordstrom-seattle-5': 452,
#  'cafe-pho-seattle': 337,
#  'cafe-yumm-seattle-2': 440,
#  'cafe-zum-zum-seattle': 281,
#  'caffè-umbria-seattle-3': 196,
#  'café-campagne-seattle-3': 185,
#  'café-frieda-seattle-3': 202,
#  'café-paloma-seattle-2': 43,
#  'campfire-bbq-seattle-7': 507,
#  'can-can-seattle': 292,
#  'cantina-de-san-patricio-seattle': 563,
#  'canton-wonton-house-seattle': 102,
#  'casco-antiguo-seattle': 25,
#  'cedars-restaurant-capitol-hill-seattle': 258,
#  'central-smoke-seattle': 310,
#  'chan-seattle-seattle-2': 41,
#  'che-sara-sara-seattle': 66,
#  'cheese-meats-bread-seattle-2': 112,
#  'cherry-street-coffee-house-seattle': 256,
#  'cherry-street-coffee-house-seattle-10': 493,
#  'cherry-street-coffee-house-seattle-11': 555,
#  'cherry-street-coffee-house-seattle-4': 426,
#  'cherry-street-public-house-seattle': 160,
#  'chew-chews-and-eatery-seattle': 480,
#  'chez-dave-seattle-2': 620,
#  'chicken-valley-seattle': 394,
#  'chip-and-drews-seattle': 545,
#  'chipotle-mexican-grill-seattle-8': 464,
#  'chocolate-and-ice-cream-delight-seattle': 596,
#  'chucks-hole-in-the-wall-bbq-seattle': 37,
#  'chuminh-tofu-and-vegan-deli-seattle': 156,
#  'cinnamon-works-seattle': 482,
#  'city-soups-seattle-2': 531,
#  'cocoa-banana-seattle': 197,
#  'collins-pub-seattle': 246,
#  'columbia-center-food-court-seattle': 211,
#  'commissary-korean-kitchen-seattle': 21,
#  'commuter-comforts-cafe-and-wine-bar-seattle': 523,
#  'cone-and-steiner-seattle-5': 354,
#  'congeez-seattle': 73,
#  'contour-seattle': 419,
#  'convoy-coffee-seattle': 264,
#  'copacabana-cafe-seattle': 481,
#  'copal-seattle': 34,
#  'core-bistro-seattle': 302,
#  'cortina-seattle-3': 65,
#  'country-dough-seattle': 193,
#  'crawfish-king-seattle-2': 217,
#  'crepe-de-france-seattle': 293,
#  'cutters-crabhouse-seattle': 184,
#  'daawat-grill-seattle-2': 121,
#  'daily-dozen-doughnut-seattle': 312,
#  'daily-grill-seattle': 487,
#  'damn-the-weather-seattle': 4,
#  'davids-and-co-seattle': 470,
#  'dead-line-seattle': 17,
#  'deez-dogz-seattle': 527,
#  'delaurenti-food-and-wine-seattle-2': 326,
#  'deli-cut-subs-seattle': 181,
#  'delicatus-seattle-2': 324,
#  'delicatus-seattle-3': 85,
#  'delinomore-seattle': 259,
#  'dim-sum-king-seattle': 163,
#  'din-tai-fung-seattle-14': 78,
#  'din-tai-fung-seattle-17': 575,
#  'doc-maynards-public-house-seattle': 439,
#  'dog-in-the-park-seattle': 329,
#  'dong-thap-noodles-seattle': 80,
#  'dough-zone-dumpling-house-seattle-2': 10,
#  'dragonfish-asian-cafe-seattle': 490,
#  'duk-li-dim-sum-seattle': 357,
#  'dunbar-room-seattle': 323,
#  'dynasty-room-seattle-5': 89,
#  'eastern-cafe-seattle': 216,
#  'edgars-cantina-seattle': 532,
#  'einstein-bros-bagels-seattle-3': 390,
#  'el-borracho-seattle': 155,
#  'el-camión-seattle-6': 177,
#  'elemental-pizza-seattle-3': 496,
#  'elephant-and-castle-seattle': 400,
#  'elliotts-oyster-house-seattle-2': 9,
#  'elysian-fields-seattle': 109,
#  'emmett-watsons-oyster-bar-seattle': 495,
#  'espresso-caffe-dior-seattle': 606,
#  'ettas-seattle-2': 296,
#  'evergreens-salad-seattle-12': 407,
#  'evergreens-salad-seattle-15': 212,
#  'evergreens-salad-seattle-2': 379,
#  'evergreens-salad-seattle-4': 330,
#  'fado-irish-pub-seattle-3': 239,
#  'falafel-king-seattle': 410,
#  'farvahar-persian-cafe-seattle': 374,
#  'ferry-noodle-house-seattle-3': 229,
#  'fiesta-fiesta-seattle': 568,
#  'flame-cafe-seattle': 168,
#  'fog-room-seattle': 134,
#  'fonte-café-seattle': 254,
#  'fort-st-george-seattle': 269,
#  'fortune-garden-seattle': 348,
#  'fresh-table-cafe-seattle-4': 535,
#  'frolik-kitchen-cocktails-seattle-2': 332,
#  'fuel-seattle-2': 341,
#  'fuji-sushi-seattle': 136,
#  'genghis-khan-restaurant-seattle': 503,
#  'georges-sausage-and-delicatessen-seattle': 164,
#  'georgian-restaurant-seattle': 207,
#  'ghost-alley-espresso-seattle': 434,
#  'girin-korean-ssam-bar-seattle': 40,
#  'goldfinch-tavern-seattle': 392,
#  'good-bar-seattle-3': 24,
#  'gopoké-seattle-5': 64,
#  'gordon-biersch-brewery-restaurant-seattle': 492,
#  'gourmet-noodle-bowl-seattle': 57,
#  'grand-central-bakery-seattle-5': 275,
#  'great-state-burger-seattle-3': 253,
#  'great-state-burger-seattle-5': 402,
#  'great-state-burger-seattle-6': 364,
#  'green-leaf-vietnamese-restaurant-seattle': 53,
#  'green-tree-food-truck-seattle': 591,
#  'grid-iron-grill-seattle': 598,
#  'grilled-cheese-experience-seattle': 243,
#  'grounders-world-famous-garlic-fries-seattle': 450,
#  'gyro-express-seattle-2': 504,
#  'gyro-house-seattle': 382,
#  'gyro-stop-mediterranean-grill-seattle': 215,
#  'h-bistro-seattle-5': 132,
#  'habitant-seattle-3': 150,
#  'hamanasu-seattle': 178,
#  'hans-deli-and-grocery-seattle': 483,
#  'happy-garden-seattle-3': 554,
#  'happy-grillmore-seattle': 219,
#  'happy-teriyaki-seattle-2': 548,
#  'harbor-café-seattle-2': 298,
#  'harbor-city-restaurant-seattle': 19,
#  'harborview-medical-center-cafeteria-seattle': 327,
#  'harborview-medical-center-maleng-café-seattle': 231,
#  'hard-rock-cafe-seattle-6': 524,
#  'hardwok-cafe-seattle': 223,
#  'harried-and-hungry-seattle-2': 373,
#  'hawks-nest-seattle': 321,
#  'heartwood-provisions-seattle-3': 42,
#  'henrys-taiwan-plus-seattle': 286,
#  'henrys-tavern-seattle-seattle': 191,
#  'herbs-thai-to-go-seattle': 552,
#  'hilltop-deli-seattle': 280,
#  'hit-it-here-cafe-and-bar-seattle': 560,
#  'ho-ho-seafood-restaurant-seattle': 314,
#  'homegrown-seattle-5': 130,
#  'honest-biscuits-seattle': 509,
#  'honey-court-seafood-restaurant-seattle-2': 242,
#  'hong-kong-bistro-seattle': 152,
#  'hooverville-bar-seattle': 267,
#  'hot-as-pho-seattle-2': 111,
#  'hot-pot-king-seattle-3': 97,
#  'house-of-hong-restaurant-seattle': 441,
#  'hue-ky-mi-gia-seattle': 144,
#  'humble-pie-seattle': 237,
#  'huong-binh-seattle': 313,
#  'i-heart-sushi-seattle': 262,
#  'i5-pho-seattle-seattle-2': 30,
#  'ibajellas-ice-cream-cane-seattle-2': 443,
#  'il-bistro-seattle': 343,
#  'il-corvo-pasta-seattle': 556,
#  'il-fornaio-seattle': 474,
#  'il-terrazzo-carmine-seattle': 67,
#  'incredibowls-seattle-2': 368,
#  'intermezzo-carmine-seattle-2': 52,
#  'ironsteak-seattle': 45,
#  'italian-family-pizza-seattle': 110,
#  'itty-bitty-schnitty-seattle': 154,
#  'ivars-acres-of-clams-seattle-7': 93,
#  'ivars-fish-bar-seattle-7': 84,
#  'j-and-m-cafe-seattle-3': 383,
#  'j-sushi-seattle': 528,
#  'jack-in-the-box-seattle-5': 567,
#  'jacks-fish-spot-seattle': 290,
#  'jade-garden-seattle': 127,
#  'james-moore-bar-and-kitchen-seattle': 122,
#  'japonessa-sushi-cocina-seattle': 28,
#  'jarrbar-seattle': 165,
#  'jasmine-thai-cuisine-seattle': 574,
#  'jasmines-grill-and-bar-seattle-3': 393,
#  'jelly-bar-seattle-2': 558,
#  'jiaozi-dumplings-house-seattle-2': 268,
#  'jimmy-johns-seattle-10': 501,
#  'jimmy-johns-seattle-11': 502,
#  'jimmy-johns-seattle-12': 600,
#  'jimmy-johns-seattle-18': 442,
#  'jimmy-johns-seattle-2': 583,
#  'jimmy-johns-seattle-3': 512,
#  'jimmy-johns-seattle-4': 595,
#  'jimmy-johns-seattle-8': 585,
#  'jimmys-on-first-seattle': 352,
#  'joelles-espresso-cafe-seattle-3': 594,
#  'joes-grilled-gourmet-dogs-seattle': 344,
#  'johnny-rockets-seattle': 588,
#  'joy-bento-seattle': 166,
#  'joyale-seafood-restaurant-seattle-2': 241,
#  'julies-garden-seattle': 147,
#  'juno-seattle': 244,
#  'justus-cafe-seattle': 540,
#  'kaname-izakaya-seattle': 250,
#  'kastoori-grill-seattle': 453,
#  'kau-kau-barbeque-seattle': 55,
#  'kebab-seattle-2': 605,
#  'kells-irish-restaurant-and-pub-seattle': 497,
#  'kidd-valley-seattle-6': 396,
#  'kigo-kitchen-seattle-2': 315,
#  'kigo-kitchen-seattle-3': 362,
#  'kigo-kitchen-seattle-6': 172,
#  'king-deli-and-espresso-seattle': 477,
#  'king-dome-deli-seattle': 530,
#  'king-noodle-seattle': 22,
#  'king-street-bar-and-oven-seattle': 436,
#  'king-street-kafe-seattle': 479,
#  'kings-barbeque-house-seattle-2': 413,
#  'la-creperie-by-ethan-stowell-seattle-3': 608,
#  'la-creperie-voila-seattle-4': 279,
#  'la-vaca-burrito-express-seattle': 449,
#  'lan-huê-sandwich-and-bakery-seattle': 94,
#  'le-panier-french-bakery-seattle': 200,
#  'le-pichet-seattle': 214,
#  'lecōsho-seattle-2': 51,
#  'liana-cafe-house-seattle': 478,
#  'little-italy-seattle-seattle': 406,
#  'little-neon-taco-seattle-3': 70,
#  'little-sheep-mongolian-hot-pot-seattle-2': 135,
#  'long-provincial-vietnamese-seattle': 137,
#  'los-agaves-seattle-4': 319,
#  'loulay-kitchen-and-bar-seattle': 143,
#  'loving-hut-seattle': 360,
#  'lowells-restaurant-seattle': 252,
#  'ludis-seattle': 82,
#  'luigis-italian-eatery-seattle-2': 115,
#  'luigis-little-italy-tour-seattle': 579,
#  'macrina-bakery-and-cafe-seattle-3': 557,
#  'mad-pizza-seattle-4': 559,
#  'madhu-cuisine-of-india-seattle-4': 533,
#  'mados-seattle-2': 49,
#  'mae-phim-thai-seattle-3': 371,
#  'mae-phim-thai-seattle-4': 399,
#  'main-street-gyros-seattle-2': 108,
#  'maneki-seattle': 33,
#  'mangia-me-seattle-2': 491,
#  'manus-bodega-seattle': 38,
#  'manus-tacos-seattle': 123,
#  'marination-mobile-seattle-5': 451,
#  'marion-court-food-court-seattle': 551,
#  'mariscos-mexico-seattle': 325,
#  'market-cafe-seattle-3': 494,
#  'market-diner-seattle': 469,
#  'market-fresh-rs-seattle-2': 266,
#  'market-fresh-seattle': 602,
#  'market-fresh-seattle-6': 403,
#  'market-grill-seattle': 106,
#  'marvs-famous-hot-dogs-seattle': 543,
#  'matts-in-the-market-seattle': 195,
#  'maxang-deli-and-cafe-seattle': 387,
#  'maximilien-seattle': 458,
#  'mccoys-firehouse-seattle': 61,
#  'mcdonalds-seattle-27': 537,
#  'measure-seattle': 614,
#  'mediterranean-cuisine-seattle': 611,
#  'mediterranean-mix-seattle': 213,
#  'mee-sum-pastry-seattle': 338,
#  'melange-market-seattle': 460,
#  'mels-market-seattle': 159,
#  'mercato-stellina-seattle-2': 511,
#  'merchants-cafe-and-saloon-seattle': 389,
#  'metropolitan-deli-and-cafe-seattle-5': 405,
#  'metropolitan-grill-seattle': 29,
#  'mi-la-cay-seattle': 288,
#  'michou-seattle': 226,
#  'mikes-noodle-house-seattle': 31,
#  'miners-landing-seattle': 376,
#  'miss-cafe-seattle-3': 228,
#  'mod-pizza-seattle-7': 232,
#  'moghul-express-seattle': 488,
#  'moore-coffee-seattle-2': 395,
#  'moore-coffee-shop-seattle': 225,
#  'mr-ds-greek-delicacies-seattle': 435,
#  'musashis-seattle-3': 75,
#  'muse-at-benaroya-hall-seattle': 430,
#  'mustard-seed-cafe-seattle': 462,
#  'naansense-seattle': 274,
#  'napkin-friends-seattle': 424,
#  'nates-wings-and-waffles-seattle': 50,
#  'new-saigon-vietnamese-restaurant-ii-seattle': 461,
#  'new-star-seafood-restaurant-seattle': 421,
#  'nijo-sushi-bar-and-grill-seattle': 198,
#  'nirmals-seattle': 2,
#  'noi-thai-cuisine-seattle-3': 72,
#  'noodle-zen-seattle': 566,
#  'nordstrom-grill-seattle-2': 380,
#  'north-shore-hawaiian-barbeque-seattle': 294,
#  'nyc-deli-market-seattle-2': 345,
#  'ocean-star-seattle': 423,
#  'off-the-rez-seattle': 398,
#  'okinawa-teriyaki-seattle': 173,
#  'old-stove-brewing-seattle-3': 161,
#  'olivers-lounge-seattle': 316,
#  'one-pot-seattle-3': 15,
#  'organic-to-go-seattle-4': 619,
#  'oriental-mart-seattle-5': 350,
#  'outlier-seattle': 90,
#  'owln-thistle-irish-pub-seattle': 342,
#  'p-f-changs-seattle': 465,
#  'pacific-cafe-hong-kong-kitchen-seattle-2': 92,
#  'palomino-seattle': 297,
#  'pane-pane-sandwiches-seattle': 455,
#  'papa-bois-seattle': 186,
#  'paseo-caribbean-food-seattle-8': 146,
#  'patagon-seattle-2': 113,
#  'peloton-seattle': 107,
#  'pho-25-seattle': 472,
#  'pho-ba-seattle-4': 88,
#  'pho-bac-súp-shop-seattle-6': 63,
#  'pho-hoa-noodle-soup-seattle-2': 358,
#  'pho-saigon-seattle-2': 363,
#  'pho-so-1-seattle': 205,
#  'pike-brewing-company-seattle': 180,
#  'pike-grocery-seattle': 411,
#  'pike-place-bar-and-grill-seattle': 521,
#  'pike-place-chinese-cuisine-seattle': 562,
#  'pike-place-chowder-seattle': 6,
#  'pike-place-chowder-seattle-4': 103,
#  'pikes-pit-bar-b-que-seattle': 175,
#  'pings-dumpling-house-seattle': 188,
#  'pings-food-market-seattle': 415,
#  'pinks-ice-cream-seattle': 245,
#  'pioneer-grill-hot-dog-stands-seattle': 581,
#  'piroshki-on-3rd-seattle-2': 104,
#  'piroshki-on-madison-seattle': 157,
#  'piroshky-piroshky-seattle': 46,
#  'piroshky-piroshky-seattle-5': 96,
#  'piroshky-piroshky-seattle-7': 418,
#  'piroshky-piroshky-seattle-8': 183,
#  'pita-xpress-seattle-4': 331,
#  'pizza-and-pasta-bar-seattle-2': 273,
#  'pizza-pro-seattle': 234,
#  'place-pigalle-seattle': 233,
#  'planet-java-diner-seattle-2': 118,
#  'poke-alice-seattle': 124,
#  'poke-lover-seattle-10': 499,
#  'poké-bar-seattle-9': 320,
#  'pokéworks-seattle': 151,
#  'post-alley-pizza-seattle': 235,
#  'potbelly-sandwich-shop-seattle-3': 427,
#  'potbelly-sandwich-shop-seattle-4': 404,
#  'potbelly-sandwich-shop-seattle-8': 367,
#  'premier-meat-pies-seattle-2': 187,
#  'primo-seattle': 459,
#  'purple-café-and-wine-bar-seattle-3': 76,
#  'purple-dot-cafe-seattle-2': 318,
#  'qdoba-mexican-eats-seattle-7': 546,
#  'quality-athletics-seattle': 133,
#  'quiznos-seattle-23': 593,
#  'radiator-whiskey-seattle': 13,
#  'rays-deli-seattle': 370,
#  'red-bowls-seattle': 48,
#  'red-cedar-and-sage-seattle': 71,
#  'red-lantern-seattle': 56,
#  'red-robin-gourmet-burgers-seattle-7': 365,
#  'redtrees-restaurant-bar-seattle': 485,
#  'regatta-bar-and-grille-seattle': 412,
#  'retro-restaurant-and-lounge-seattle': 255,
#  'revolution-pizza-and-music-seattle': 220,
#  'ricenroll-seattle-2': 612,
#  'rider-seattle': 190,
#  'rn74-seattle': 171,
#  'rolls-n-sushi-seattle': 489,
#  'rub-with-love-shack-seattle': 446,
#  'ruths-chris-steak-house-seattle': 369,
#  'rview-seattle': 428,
#  'saba-ethiopian-cuisine-seattle': 218,
#  'saffron-spice-seattle': 522,
#  'saigon-bistro-seattle-2': 471,
#  'saigon-deli-seattle': 206,
#  'saigon-vietnam-deli-seattle': 384,
#  'sake-nomi-seattle': 138,
#  'salumi-artisan-cured-meats-seattle-2': 32,
#  'samurai-noodle-seattle': 204,
#  'sansei-seafood-restaurant-and-sushi-bar-seattle-3': 227,
#  'sarduccis-specialty-subs-seattle': 238,
#  'scout-seattle': 247,
#  'seatown-seabar-seattle': 408,
#  'seattle-aquarium-cafe-seattle': 486,
#  'seattle-art-museum-seattle': 158,
#  'seattle-bagel-bakery-seattle-5': 517,
#  'seattle-deli-seattle': 339,
#  'secret-sausage-seattle': 221,
#  'seoul-bowl-seattle': 77,
#  'seoul-tofu-house-seattle': 248,
#  'seven-stars-pepper-szechuan-restaurant-seattle': 438,
#  'shaker-and-spear-seattle-2': 87,
#  'shanghai-garden-seattle-4': 372,
#  'sharetea-seattle-5': 169,
#  'shawn-o-donnells-american-grill-and-irish-pub-seattle-2': 20,
#  'shilla-korean-bbq-seattle': 194,
#  'shuckers-oyster-bar-seattle': 128,
#  'shucky-muckers-seattle': 576,
#  'sichuanese-cuisine-seattle': 69,
#  'silver-spork-food-truck-seattle': 586,
#  'sisters-european-snacks-seattle': 597,
#  'sizzling-pot-king-seattle-2': 14,
#  'sky-view-cafe-seattle': 114,
#  'slice-box-pizza-seattle': 282,
#  'sluggers-seattle-seattle': 284,
#  'smith-tower-observatory-bar-seattle-2': 68,
#  'smith-tower-provisions-seattle-2': 467,
#  'song-phang-kong-seattle': 125,
#  'sonyas-bar-and-grill-and-event-space-seattle': 484,
#  'sound-soups-seattle': 416,
#  'sound-view-cafe-seattle': 590,
#  'soups-du-jour-seattle': 516,
#  'soups-on-seattle-2': 565,
#  'specialtys-café-and-bakery-seattle-30': 425,
#  'specialtys-café-and-bakery-seattle-31': 447,
#  'specialtys-café-and-bakery-seattle-32': 454,
#  'specialtys-café-and-bakery-seattle-34': 417,
#  'specialtys-café-and-bakery-seattle-35': 385,
#  'spin-seattle-seattle': 100,
#  'sprigy-seattle-2': 265,
#  'spring-roll-house-deli-seattle': 192,
#  'spring-thyme-bakeshop-seattle': 361,
#  'sprout-seattle': 44,
#  'steak-n-shake-seattle': 251,
#  'steelhead-diner-seattle': 272,
#  'stella-fiore-wood-fired-pizza-seattle-3': 131,
#  'subway-seattle-28': 538,
#  'subway-seattle-3': 615,
#  'subway-seattle-31': 617,
#  'subway-seattle-34': 584,
#  'subway-seattle-37': 603,
#  'subway-seattle-59': 582,
#  'subway-seattle-6': 601,
#  'subway-seattle-64': 549,
#  'subway-seattle-66': 618,
#  'subway-seattle-91': 599,
#  'sugar-bakery-and-cafe-seattle-3': 189,
#  'sun-bakery-and-cafe-seattle': 381,
#  'sushi-kanpai-seattle': 153,
#  'sushi-kashiba-seattle': 99,
#  'sushi-kudasai-seattle': 301,
#  'sushi-kudasai-seattle-2': 291,
#  'sushi-kudasai-seattle-3': 463,
#  'swannies-seattle': 505,
#  'sweet-iron-waffles-seattle-5': 81,
#  'swingin-wings-with-chef-ethan-stowell-seattle': 300,
#  'szechuan-fish-seattle': 236,
#  'szechuan-noodle-bowl-seattle': 119,
#  't-js-deli-seattle': 422,
#  'taco-del-mar-seattle-15': 544,
#  'taco-del-mar-seattle-19': 468,
#  'taco-del-mar-seattle-28': 578,
#  'taco-del-mar-seattle-42': 270,
#  'taco-del-mar-seattle-7': 609,
#  'tai-tung-chinese-restaurant-seattle': 285,
#  'tam-noodle-box-seattle': 224,
#  'tamarind-tree-seattle': 35,
#  'tandoozy-seattle': 500,
#  'tankard-and-tun-seattle-2': 222,
#  'tap-house-grill-seattle-3': 230,
#  'taqueria-el-ranchero-seattle': 306,
#  'taste-cafe-seattle-3': 514,
#  'taste-of-asia-seattle-2': 573,
#  'taste-of-the-caribbean-seattle-2': 91,
#  'tats-delicatessen-seattle': 18,
#  'tats-truck-seattle': 397,
#  'taxi-dogs-seattle': 570,
#  'taylor-shellfish-oyster-bar-seattle-2': 8,
#  'ten-sushi-35-seattle-2': 182,
#  'tenoch-mexican-grill-seattle': 359,
#  'thai-2-go-seattle-3': 409,
#  'thai-curry-simple-seattle-5': 116,
#  'thai-ginger-pacific-place-seattle': 456,
#  'thai-ginger-seattle-5': 569,
#  'thai-place-seattle': 513,
#  'thai-star-restaurant-seattle': 378,
#  'thai-taste-restaurant-seattle': 346,
#  'thanh-son-tofu-seattle-3': 351,
#  'thanh-vi-seattle': 429,
#  'the-515-seattle-3': 431,
#  'the-athenian-seafood-restaurant-and-bar-seattle-2': 448,
#  'the-berliner-döner-kebab-seattle-3': 86,
#  'the-bistro-at-courtyard-seattle': 334,
#  'the-brooklyn-seafood-steak-and-oyster-house-seattle': 101,
#  'the-capital-grille-seattle': 139,
#  'the-central-saloon-seattle': 386,
#  'the-cheesecake-factory-seattle': 295,
#  'the-crab-pot-seattle-2': 74,
#  'the-crumpet-shop-seattle': 176,
#  'the-diller-room-seattle': 333,
#  'the-dinner-detective-interactive-murder-mystery-dinner-show-seattle': 561,
#  'the-fig-and-the-judge-seattle-2': 58,
#  'the-fishermans-restaurant-seattle': 170,
#  'the-frankfurter-seattle-2': 432,
#  'the-hart-and-the-hunter-seattle-2': 36,
#  'the-juicy-café-seattle': 304,
#  'the-juicy-café-seattle-5': 199,
#  'the-little-london-plane-seattle-2': 129,
#  'the-lodge-sports-grille-downtown-seattle': 347,
#  'the-lodge-sports-grille-seattle': 391,
#  'the-london-plane-seattle-3': 11,
#  'the-natural-seattle': 572,
#  'the-organic-coup-seattle': 401,
#  'the-original-deli-seattle-4': 210,
#  'the-peak-cafe-seattle': 444,
#  'the-peoples-burger-seattle': 105,
#  'the-pink-door-seattle-4': 1,
#  'the-rhododendron-cafe-seattle': 174,
#  'the-salmon-cooker-seattle': 553,
#  'the-taproom-at-pike-place-seattle': 208,
#  'the-triple-door-seattle': 375,
#  'third-ave-cafe-seattle': 520,
#  'tofully-seattle-2': 26,
#  'ton-kiang-barbeque-noodle-house-seattle': 167,
#  'top-pot-doughnuts-seattle-7': 577,
#  'torchys-restaurant-bar-and-den-seattle': 476,
#  'tossd-seattle': 289,
#  'trace-seattle': 278,
#  'triangle-pub-seattle': 117,
#  'tsukushinbo-seattle': 7,
#  'tulio-seattle': 149,
#  'tummy-yummy-thai-seattle': 610,
#  'turkish-delight-seattle': 283,
#  'twice-burger-seattle-3': 257,
#  'u-bank-cafe-seattle': 616,
#  'ulis-famous-sausage-seattle': 309,
#  'umai-sushi-and-teriyaki-seattle': 526,
#  'ummas-lunch-box-seattle': 16,
#  'unconventional-pizza-seattle': 592,
#  'union-deli-la-puget-sound-plaza-building-seattle': 613,
#  'union-square-seattle': 366,
#  'urara-seattle-2': 335,
#  'veggie-grill-seattle-6': 263,
#  'vietnam-house-seattle': 356,
#  'virginia-inn-seattle': 542,
#  'vitos-seattle': 162,
#  'vons-1000-spirits-seattle-4': 95,
#  'vovito-seattle': 536,
#  'voxx-coffee-downtown-seattle-2': 388,
#  'walla-walla-farms-seattle': 305,
#  'walla-walla-farms-seattle-3': 353,
#  'way-back-crab-shack-seattle': 142,
#  'west-edge-market-seattle': 541,
#  'where-ya-at-matt-seattle': 62,
#  'wild-fish-poke-seattle': 249,
#  'wild-ginger-seattle': 287,
#  'wild-rye-cafe-bakery-seattle': 547,
#  'wild-tiger-pizza-seattle-3': 580,
#  'wildfire-taqueria-seattle': 519,
#  'world-fresh-asian-eatery-seattle': 475,
#  'world-fresh-eatery-seattle': 355,
#  'world-pizza-seattle': 377,
#  'y-and-a-cafe-seattle': 261,
#  'yard-house-seattle': 271,
#  'yoshino-teriyaki-seattle': 260,
#  'zaccagnis-seattle-2': 141,
#  'zeitgeist-coffee-seattle': 209,
#  'zig-zag-cafe-seattle-2': 79,
#  'ziti-italiano-pizza-seattle': 589,
#  'zobel-seattle': 508,
#  'zócalo-seattle-4': 83}

# %%
more_than_one_review['item_id'] = more_than_one_review['alias'].apply(alias_dict.get)
# Out:
# /Users/gnishimura/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
user_ids = more_than_one_review['userid'].unique()

# %%
user_id = zip(user_ids, range(len(user_ids)))

# %%
user_dict = dict(user_id)

# %%
more_than_one_review['user_id'] = more_than_one_review['userid'].apply(user_dict.get)
# Out:
# /Users/gnishimura/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
more_than_one_review['date'] = pd.to_datetime(more_than_one_review['date'], errors='input')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-54-38252ba3edc5> in <module>()
# ----> 1 more_than_one_review['date'] = pd.to_datetime(more_than_one_review['date'], errors='input')
#
# /Users/gnishimura/anaconda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     449         else:
#     450             from pandas import Series
# --> 451             values = _convert_listlike(arg._values, True, format)
#     452             result = Series(values, index=arg.index, name=arg.name)
#     453     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /Users/gnishimura/anaconda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     366                     dayfirst=dayfirst,
#     367                     yearfirst=yearfirst,
# --> 368                     require_iso8601=require_iso8601
#     369                 )
#     370
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# AssertionError:

# %%
s = '8/24/2018\n            \n\n\n\n\n\nUpdated review'

s.partition('\n')[0]
# Out:
# '8/24/2018'

# %%
more_than_one_review['date'] = more_than_one_review['date'].apply(lambda x: x.partition('\n')[0])
# Out:
# /Users/gnishimura/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
more_than_one_review['date'] = pd.to_datetime(more_than_one_review['date'])
# Out:
# /Users/gnishimura/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#more_than_one_review.sort_values('date')

# %%
pruned_df = more_than_one_review.drop(['_id', 'href', 'review_text', 'userid', 'username', 'alias'], axis=1)

# %%
sorted_pruned_df = pruned_df.sort_values('date')

# %%
sorted_pruned_df.to_pickle('als_df.pkl')

# %%
more_than_one_review.to_pickle('more_than_one_review_df.pkl')
